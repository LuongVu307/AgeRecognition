# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
print(os.listdir())
os.chdir("drive/MyDrive/Age Recognition")
os.getcwd()
# Out:
# ['.config', 'drive', 'sample_data']
# '/content/drive/MyDrive/Age Recognition'

# %%
from tensorflow.keras.models import load_model
import cv2
import os
from os.path import join
import numpy as np
import matplotlib.pyplot as plt

prediction_dct = {0 : '25-30', 1 : '42-48',2 : '6-20',3 : '60-98'}

MAIN_PATH = os.getcwd()
model = load_model(join(MAIN_PATH, "AgeRecognition.h5"))


image = cv2.imread(join(MAIN_PATH, 'example.jpg'))
image = cv2.resize(image, (200, 200))

final_image = np.expand_dims(image, 0)
prediction = model.predict(final_image)

print("FINAL_PREDICTION: YOU'RE ", prediction_dct[np.argmax(prediction)], "YEARS OLD")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# 1/1 [==============================] - 1s 579ms/step
# FINAL_PREDICTION: YOU'RE  60-98 YEARS OLD
